# %%
from yolo import YOLO
yolo_model = YOLO(model_path='saved_model/trained_weights.h5')
# Out:
# D:\program\ANACONDA\lib\site-packages\h5py\__init__.py:36: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters
# Using TensorFlow backend.

# %%
with open('dataset_test.txt') as file:
    line_list = file.readlines()
jpgFilePath_list = [k.split()[0] for k in line_list]
jpgFilePath_list
jpgFilePath_list
# Out:
# ['images_416x416\\178.jpg',
#  'images_416x416\\150.jpg',
#  'images_416x416\\005.jpg',
#  'images_416x416\\180.jpg',
#  'images_416x416\\036.jpg',
#  'images_416x416\\092.jpg',
#  'images_416x416\\113.jpg',
#  'images_416x416\\077.jpg',
#  'images_416x416\\197.jpg',
#  'images_416x416\\125.jpg',
#  'images_416x416\\200.jpg',
#  'images_416x416\\139.jpg',
#  'images_416x416\\021.jpg',
#  'images_416x416\\054.jpg',
#  'images_416x416\\190.jpg',
#  'images_416x416\\099.jpg',
#  'images_416x416\\149.jpg',
#  'images_416x416\\065.jpg',
#  'images_416x416\\067.jpg',
#  'images_416x416\\138.jpg']

# %%
from PIL import Image

jpgFilePath = jpgFilePath_list[8]
image = Image.open(jpgFilePath)
yolo_model.detect_image(image)
# Out:
# 检测这张图片用时2.13秒
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=416x416 at 0x80E3048>
